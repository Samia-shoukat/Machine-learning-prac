# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from mlxtend.plotting import plot_decision_regions

# %%
dataset = pd.read_csv(r"E:\Machine Learning\placement-dataset.csv")

# %%
dataset.head(4)
# Out:
#    cgpa  score  placement
# 0   6.8    123          1
# 1   5.9    106          0
# 2   5.3    121          0
# 3   7.4    132          1

# %%
sns.scatterplot(x="cgpa",y="score",data=dataset,hue="placement")
plt.show()

# %%
x = dataset.iloc[:,:-1]
y = dataset["placement"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test =train_test_split(x,y,test_size=0.2, random_state=42)

# %%
'linear' , 'poly', 'rbf' , 'sigmoid' , 'precomputed'
# Out:
# ('linear', 'poly', 'rbf', 'sigmoid', 'precomputed')

# %%
from sklearn.svm import SVC

# %%
sv = SVC(kernel="linear")
sv.fit(x_train,y_train)
# Out:
# SVC(kernel='linear')

# %%
sv.score(x_test,y_test)*100
# Out:
# 95.0

# %%
sv.score(x_train,y_train)*100
# Out:
# 91.25

# %%
plot_decision_regions(x.to_numpy(),y.to_numpy(),clf=sv)
plt.show()
# Out:
# C:\Users\Dell\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
